# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# wnrr

before = 5500
generation = np.array([72, 73, 78, 85, 84])/60

wn_complex = {
    'evaluation': np.array([250, 260, 257, 250, 246])/60,
    'total': np.array([322, 333, 335, 335, 330])/60,
    'after': np.array([59, 87, 80, 84, 114]),
    'mrr': np.array([0.0143937, 0.0116354, 0.0327706, 0.0150634, 0.0101352]),
    'eff': np.array([660, 941, 860, 903, 1244])
}

wn_conve = {
    'evaluation': np.array([353, 353, 358, 353, 365])/60,
    'total': np.array([425, 426, 436, 438, 449])/60,
    'after': np.array([88, 257, 258, 183, 231]),
    'mrr': np.array([0.0061636, 0.0873476, 0.0150937, 0.0072535, 0.0299462]),
    'eff': np.array([745, 2172, 2130, 1504, 1852])
}

wn_distmult = {
    'evaluation': np.array([335, 324, 331, 330, 325])/60,
    'total': np.array([407, 397, 409, 415, 409])/60,
    'after': np.array([90, 140, 146, 96, 194]),
    'mrr': np.array([0.0099869, 0.0093968, 0.0149792, 0.0073614, 0.0137459]),
    'eff': np.array([796, 1270, 1285, 833, 1708])
}

wn_rescal = {
    'evaluation': np.array([216, 204, 204, 215, 203])/60,
    'total': np.array([288, 277, 282, 300, 287])/60,
    'after': np.array([78, 120, 169, 100, 172]),
    'mrr': np.array([0.0084879, 0.0094251, 0.0212943, 0.0090652, 0.0182477]),
    'eff': np.array([975, 1560, 2157, 1200, 2157])
}

wn_rotate = {
    'evaluation': np.array([11026, 10983, 11001, 11031, 10999])/60,
    'total': np.array([11098, 11056, 11079, 11116, 11083])/60,
    'after': np.array([71, 57, 48, 62, 34]),
    'mrr': np.array([0.0085398, 0.0076820, 0.0364341, 0.0121511, 0.0130263]),
    'eff': np.array([23, 19, 16, 20, 11])
}

wn_transe = {
    'evaluation': np.array([336, 335, 339, 333, 338])/60,
    'total': np.array([408, 408, 417, 418, 422])/60,
    'after': np.array([101, 108, 144, 109, 188]),
    'mrr': np.array([0.0061612, 0.0075645, 0.0238642, 0.0062610, 0.0157031]),
    'eff': np.array([891, 953, 1243, 939, 1604])
}

dicts = [wn_complex, wn_conve, wn_distmult, wn_rescal, wn_transe]
groups = ['UR', 'EF', 'GD', 'CC', 'CT']

# Initialize lists to store the 'total' values for each group
ur_wn_gen = []
ef_wn_gen = []
gd_wn_gen = []
cc_wn_gen = []
ct_wn_gen = []

ur_wn_mrr = []
ef_wn_mrr = []
gd_wn_mrr = []
cc_wn_mrr = []
ct_wn_mrr = []

ur_wn_eff = []
ef_wn_eff = []
gd_wn_eff = []
cc_wn_eff = []
ct_wn_eff = []

for dict in dicts:
    ur_wn_gen.append(dict['total'][0])
    ef_wn_gen.append(dict['total'][1])
    gd_wn_gen.append(dict['total'][2])
    cc_wn_gen.append(dict['total'][3])
    ct_wn_gen.append(dict['total'][4])

    ur_wn_mrr.append(dict['mrr'][0])
    ef_wn_mrr.append(dict['mrr'][1])
    gd_wn_mrr.append(dict['mrr'][2])
    cc_wn_mrr.append(dict['mrr'][3])
    ct_wn_mrr.append(dict['mrr'][4])

    

    ur_wn_eff.append(dict['eff'][0])
    ef_wn_eff.append(dict['eff'][1])
    gd_wn_eff.append(dict['eff'][2])
    cc_wn_eff.append(dict['eff'][3])
    ct_wn_eff.append(dict['eff'][4])

# %%
# fb15k-237

before = 118500
generation = np.array([5197, 5182, 5493, 9643, 9614])/60

fb_complex = {
    'evaluation': np.array([1806, 1774, 1858, 1772, 1816])/60,
    'total': np.array([7003, 6956, 7351, 11415, 11430])/60,
    'after': np.array([5503, 10688, 8882, 5248, 14605]),
    'mrr': np.array([0.0107834, 0.0498544, 0.0258024, 0.0100205, 0.0487693]),
    'eff': np.array([2829, 5531, 4350, 1655, 4600])
}

fb_conve = {
    'evaluation': np.array([1951, 1932, 1847, 1942, 1823])/60,
    'total': np.array([7148, 7114, 7340, 11585, 11437])/60,
    'after': np.array([7065, 13340, 12603, 7227, 28256]),
    'mrr': np.array([0.0090541, 0.0687291, 0.0194467, 0.0123923, 0.0554625]),
    'eff': np.array([3558, 6751, 6181, 2246, 8894])
}

fb_distmult = {
    'evaluation': np.array([1430, 1445, 1452, 1412, 1431])/60,
    'total': np.array([6627, 6627, 6945, 11055, 11045])/60,
    'after': np.array([4977, 9043, 7784, 5171, 14943]),
    'mrr': np.array([0.0092310, 0.0495463, 0.0229639, 0.0084581, 0.0566755]),
    'eff': np.array([2704, 4912, 4035, 1684, 4871])
}

fb_rescal = {
    'evaluation': np.array([1704, 1682, 1679, 1714, 1650])/60,
    'total': np.array([6901, 6864, 7172, 11357, 11264])/60,
    'after': np.array([286, 3455, 3441, 394, 15521]),
    'mrr': np.array([0.0052562, 0.0125153, 0.0082051, 0.0051285, 0.0184390]),
    'eff': np.array([149, 1812, 1727, 125, 4961])
}

fb_rotate = {
    'evaluation': [],
    'total': [],
    'after': [],
    'mrr': [],
    'eff': []
}

fb_transe = {
    'evaluation': np.array([1047, 1052, 1043, 1010, 1042])/60,
    'total': np.array([6244, 6234, 6536, 10653, 10656])/60,
    'after': np.array([5383, 9794, 8012, 6792, 27180]),
    'mrr': np.array([0.0125288, 0.0239662, 0.0259832, 0.0125498, 0.0427008]),
    'eff': np.array([3104, 5656, 4413, 2295, 9182])
}

dicts = [fb_complex, fb_conve, fb_distmult, fb_rescal, fb_transe]
groups = ['UR', 'EF', 'GD', 'CC', 'CT']

# Initialize lists to store the 'total' values for each group
ur_fb_gen = []
ef_fb_gen = []
gd_fb_gen = []
cc_fb_gen = []
ct_fb_gen = []

ur_fb_mrr = []
ef_fb_mrr = []
gd_fb_mrr = []
cc_fb_mrr = []
ct_fb_mrr = []

ur_fb_eff = []
ef_fb_eff = []
gd_fb_eff = []
cc_fb_eff = []
ct_fb_eff = []

for dict in dicts:
    ur_fb_gen.append(dict['total'][0])
    ef_fb_gen.append(dict['total'][1])
    gd_fb_gen.append(dict['total'][2])
    cc_fb_gen.append(dict['total'][3])
    ct_fb_gen.append(dict['total'][4])

    ur_fb_mrr.append(dict['mrr'][0])
    ef_fb_mrr.append(dict['mrr'][1])
    gd_fb_mrr.append(dict['mrr'][2])
    cc_fb_mrr.append(dict['mrr'][3])
    ct_fb_mrr.append(dict['mrr'][4])

    ur_fb_eff.append(dict['eff'][0])
    ef_fb_eff.append(dict['eff'][1])
    gd_fb_eff.append(dict['eff'][2])
    cc_fb_eff.append(dict['eff'][3])
    ct_fb_eff.append(dict['eff'][4])

# %%
#codex-l

before = 34500
generation = np.array([2987, 3024, 3251, 20249, 20305])/60

cd_complex = {
    'evaluation': np.array([3679, 3547, 3590, 3526, 3547])/60,
    'total': np.array([6666, 6571, 6841, 23775, 23852])/60,
    'after': np.array([405, 1426, 1150, 317, 1776]),
    'mrr': np.array([0.0139549, 0.0568254, 0.0500956, 0.0082232, 0.0354913]),
    'eff': np.array([219, 781, 605, 48, 268])
}

cd_conve = {
    'evaluation': np.array([3249, 3252, 3251, 3277, 3226])/60,
    'total': np.array([6236, 6276, 6502, 23526, 23531])/60,
    'after': np.array([289, 851, 1127, 479, 4383]),
    'mrr': np.array([0.0053620, 0.0229691, 0.0299186, 0.0095511, 0.0122954]),
    'eff': np.array([167, 488, 624, 73, 671])
}

cd_distmult = {
    'evaluation': np.array([2901, 2900, 2903, 2978, 2900])/60,
    'total': np.array([5888, 5924, 6154, 23227, 23205])/60,
    'after': np.array([118, 273, 533, 74, 975]),
    'mrr': np.array([0.0072619, 0.0140576, 0.0112670, 0.0077673, 0.0164444]),
    'eff': np.array([72, 166, 312, 11, 151])
}

cd_rescal = {
    'evaluation': np.array([2683, 2658, 2627, 2636, 2603])/60,
    'total': np.array([5670, 5682, 5878, 22885, 22908])/60,
    'after': np.array([73, 261, 421, 32, 952]),
    'mrr': np.array([0.0060740, 0.0067682, 0.0100130, 0.0060463, 0.0099162]),
    'eff': np.array([46, 165, 258, 5, 150])
}

cd_rotate = {
    'evaluation': None,
    'total': None,
    'after': None,
    'mrr': None,
    'eff': None
}

cd_transe = {
    'evaluation': np.array([2348, 2365, 2363, 2326, 2314])/60,
    'total': np.array([5335, 5389, 5614, 22575, 22619])/60,
    'after': np.array([438, 755, 788, 491, 4404]),
    'mrr': np.array([0.0130423, 0.0277717, 0.0342895, 0.0106523, 0.0186820]),
    'eff': np.array([296, 504, 505, 78, 701])
}

dicts = [cd_complex, cd_conve, cd_distmult, cd_rescal, cd_transe]
groups = ['UR', 'EF', 'GD', 'CC', 'CT']

# Initialize lists to store the 'total' values for each group
ur_cd_gen = []
ef_cd_gen = []
gd_cd_gen = []
cc_cd_gen = []
ct_cd_gen = []

ur_cd_mrr = []
ef_cd_mrr = []
gd_cd_mrr = []
cc_cd_mrr = []
ct_cd_mrr = []

ur_cd_eff = []
ef_cd_eff = []
gd_cd_eff = []
cc_cd_eff = []
ct_cd_eff = []

for dict in dicts:
    ur_cd_gen.append(dict['total'][0])
    ef_cd_gen.append(dict['total'][1])
    gd_cd_gen.append(dict['total'][2])
    cc_cd_gen.append(dict['total'][3])
    ct_cd_gen.append(dict['total'][4])

    ur_cd_mrr.append(dict['mrr'][0])
    ef_cd_mrr.append(dict['mrr'][1])
    gd_cd_mrr.append(dict['mrr'][2])
    cc_cd_mrr.append(dict['mrr'][3])
    ct_cd_mrr.append(dict['mrr'][4])

    ur_cd_eff.append(dict['eff'][0])
    ef_cd_eff.append(dict['eff'][1])
    gd_cd_eff.append(dict['eff'][2])
    cc_cd_eff.append(dict['eff'][3])
    ct_cd_eff.append(dict['eff'][4])

# %%
#yago3-10

before = 18500
generation = np.array([3304, 3345, 3608, 23650, 23675])/60

yg_complex = {
    'evaluation': np.array([3005, 3042, 3005, 2983, 3001])/60,
    'total': np.array([6309, 6387, 6613, 26633, 26676])/60,
    'after': np.array([75, 138, 111, 38, 390]),
    'mrr': np.array([0.0104551, 0.0095461, 0.0087921, 0.0054316, 0.0243843]),
    'eff': np.array([43, 78, 60, 5, 53])
}

yg_conve = {
    'evaluation': np.array([2695, 2736, 2719, 2724, 2695])/60,
    'total': np.array([5999, 6081, 6327, 26374, 26370])/60,
    'after': np.array([49, 636, 650, 352, 4999]),
    'mrr': np.array([0.0060161, 0.0984307, 0.0336463, 0.0053009, 0.0263620]),
    'eff': np.array([29, 377, 370, 48, 682])
}

yg_distmult = {
    'evaluation': np.array([2544, 2571, 2526, 2539, 2534])/60,
    'total': np.array([5848, 5916, 6134, 26189, 26209])/60,
    'after': np.array([76, 220, 233, 80, 804]),
    'mrr': np.array([0.0072922, 0.0279869, 0.0247117, 0.0098303, 0.0211034]),
    'eff': np.array([47, 134, 137, 11, 110])
}

yg_rescal = {
    'evaluation': np.array([2552, 2579, 2572, 2555, 2561])/60,
    'total': np.array([5856, 5924, 6180, 26205, 26236])/60,
    'after': np.array([44, 58, 78, 28, 135]),
    'mrr': np.array([0.0063679, 0.0055261, 0.0058163, 0.0060017, 0.0071551]),
    'eff': np.array([27, 35, 45, 4, 19])
}

yg_rotate = {
    'evaluation': None,
    'total': None,
    'after': None,
    'mrr': None,
    'eff': None
}

yg_transe = {
    'evaluation': np.array([2087, 2077, 2081, 2059, 2073])/60,
    'total': np.array([5391, 5422, 5689, 25709, 25748])/60,
    'after': np.array([55, 190, 269, 79, 3760]),
    'mrr': np.array([0.0049583, 0.0258750, 0.0368004, 0.0041191, 0.0232097]),
    'eff': np.array([37, 126, 170, 11, 526])
}

dicts = [yg_complex, yg_conve, yg_distmult, yg_rescal, yg_transe]
groups = ['UR', 'EF', 'GD', 'CC', 'CT']

# Initialize lists to store the 'total' values for each group
ur_yg_gen = []
ef_yg_gen = []
gd_yg_gen = []
cc_yg_gen = []
ct_yg_gen = []

ur_yg_mrr = []
ef_yg_mrr = []
gd_yg_mrr = []
cc_yg_mrr = []
ct_yg_mrr = []

ur_yg_eff = []
ef_yg_eff = []
gd_yg_eff = []
cc_yg_eff = []
ct_yg_eff = []

for dict in dicts:
    ur_yg_gen.append(dict['total'][0])
    ef_yg_gen.append(dict['total'][1])
    gd_yg_gen.append(dict['total'][2])
    cc_yg_gen.append(dict['total'][3])
    ct_yg_gen.append(dict['total'][4])

    ur_yg_mrr.append(dict['mrr'][0])
    ef_yg_mrr.append(dict['mrr'][1])
    gd_yg_mrr.append(dict['mrr'][2])
    cc_yg_mrr.append(dict['mrr'][3])
    ct_yg_mrr.append(dict['mrr'][4])

    ur_yg_eff.append(dict['eff'][0])
    ef_yg_eff.append(dict['eff'][1])
    gd_yg_eff.append(dict['eff'][2])
    cc_yg_eff.append(dict['eff'][3])
    ct_yg_eff.append(dict['eff'][4])

# %%
# Runtime

# Use LaTeX font rendering
plt.rc('text', usetex=True)
plt.rc('font', family='serif')


# Group names
groups = ['UR', 'EF', 'GD', 'CC', 'CT']

# Bar colors
bar_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

# Bar plot
x = np.arange(len(groups))
width = 0.15

fig, axs = plt.subplots(2, 2, figsize=(10, 6))
axs = axs.flatten()

rects1 = axs[0].bar(x, fb_complex['total'], width, color=bar_colors[0], label='ComplEx', edgecolor='black')
rects2 = axs[0].bar(x + width, fb_conve['total'], width, color=bar_colors[1], label='ConvE', edgecolor='black')
rects3 = axs[0].bar(x + 2 * width, fb_distmult['total'], width, color=bar_colors[2], label='DistMult', edgecolor='black')
rects4 = axs[0].bar(x + 3 * width, fb_rescal['total'], width, color=bar_colors[3], label='RESCAL', edgecolor='black')
rects5 = axs[0].bar(x + 4 * width, fb_transe['total'], width, color=bar_colors[4], label='TransE', edgecolor='black')

rects1 = axs[1].bar(x, wn_complex['total'], width, color=bar_colors[0], label='ComplEx', edgecolor='black')
rects2 = axs[1].bar(x + width, wn_conve['total'], width, color=bar_colors[1], label='ConvE', edgecolor='black')
rects3 = axs[1].bar(x + 2 * width, wn_distmult['total'], width, color=bar_colors[2], label='DistMult', edgecolor='black')
rects4 = axs[1].bar(x + 3 * width, wn_rescal['total'], width, color=bar_colors[3], label='RESCAL', edgecolor='black')
rects5 = axs[1].bar(x + 4 * width, wn_transe['total'], width, color=bar_colors[4], label='TransE', edgecolor='black')

rects1 = axs[2].bar(x, cd_complex['total'], width, color=bar_colors[0], label='ComplEx', edgecolor='black')
rects2 = axs[2].bar(x + width, cd_conve['total'], width, color=bar_colors[1], label='ConvE', edgecolor='black')
rects3 = axs[2].bar(x + 2 * width, cd_distmult['total'], width, color=bar_colors[2], label='DistMult', edgecolor='black')
rects4 = axs[2].bar(x + 3 * width, cd_rescal['total'], width, color=bar_colors[3], label='RESCAL', edgecolor='black')
rects5 = axs[2].bar(x + 4 * width, cd_transe['total'], width, color=bar_colors[4], label='TransE', edgecolor='black')

rects1 = axs[3].bar(x, yg_complex['total'], width, color=bar_colors[0], label='ComplEx', edgecolor='black')
rects2 = axs[3].bar(x + width, yg_conve['total'], width, color=bar_colors[1], label='ConvE', edgecolor='black')
rects3 = axs[3].bar(x + 2 * width, yg_distmult['total'], width, color=bar_colors[2], label='DistMult', edgecolor='black')
rects4 = axs[3].bar(x + 3 * width, yg_rescal['total'], width, color=bar_colors[3], label='RESCAL', edgecolor='black')
rects5 = axs[3].bar(x + 4 * width, yg_transe['total'], width, color=bar_colors[4], label='TransE', edgecolor='black')


# Set titles with bold formatting (this will mimic LaTeX's bold, but won't be exactly the same)
axs[0].set_xlabel(r"\textbf{(a) FB15K-237}", fontsize=18)
axs[1].set_xlabel(r"\textbf{(b) WN18RR}", fontsize=18)
axs[2].set_xlabel(r"\textbf{(c) CoDEx-L}", fontsize=18)
axs[3].set_xlabel(r"\textbf{(d) YAGO3-10}", fontsize=18)

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Setting font sizes
for ax in axs:
    ax.set_title(ax.get_title(), fontsize=16)
    ax.set_ylabel('Time (min)', fontsize=16)
    ax.set_xticks(x + 2 * width)
    ax.set_xticklabels(groups, fontsize=16)
    for label in ax.get_yticklabels():
        label.set_fontsize(16)

# Add a common legend at the top
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.99), ncol=5, prop={'size': 16})


# Display the plot
plt.show()

# %%
# Correct one

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# New data structure
data_by_strategy = {
    'FB15K-237': [ur_fb_mrr, ef_fb_mrr, gd_fb_mrr, cc_fb_mrr, ct_fb_mrr],
    'WN18RR': [ur_wn_mrr, ef_wn_mrr, gd_wn_mrr, cc_wn_mrr, ct_wn_mrr],
    'CoDEx-L': [ur_cd_mrr, ef_cd_mrr, gd_cd_mrr, cc_cd_mrr, ct_cd_mrr],
    'YAGO3-10': [ur_yg_mrr, ef_yg_mrr, gd_yg_mrr, cc_yg_mrr, ct_yg_mrr]
}

# Strategy names
strategies = ['UR', 'EF', 'GD', 'CC', 'CT']

# Models
models = ['ComplEx', 'ConvE', 'DistMult', 'RESCAL', 'TransE']

# Bar colors
bar_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

# Bar plot configuration
x = np.arange(len(strategies))
width = 0.15

fig, axs = plt.subplots(2, 2, figsize=(10, 6))
axs = axs.flatten()
titles = ["FB15K-237", "WN18RR", "CoDEx-L", "YAGO3-10"]

for ax_index, (ax, title) in enumerate(zip(axs, titles)):
    data_for_title = data_by_strategy[title]
    for model_index, model in enumerate(models):
        mrr_values = [strategy_data[model_index] for strategy_data in data_for_title]
        ax.bar(x + model_index * width, mrr_values, width, color=bar_colors[model_index], label=model, edgecolor='black')
    # ax.set_title(title)
    ax.set_ylabel('MRR')
    ax.set_xticks(x + 2 * width)
    ax.set_xticklabels(strategies)

# Set titles with bold formatting (this will mimic LaTeX's bold, but won't be exactly the same)
axs[0].set_xlabel(r"\textbf{(a) FB15K-237}", fontsize=18)
axs[1].set_xlabel(r"\textbf{(b) WN18RR}", fontsize=18)
axs[2].set_xlabel(r"\textbf{(c) CoDEx-L}", fontsize=18)
axs[3].set_xlabel(r"\textbf{(d) YAGO3-10}", fontsize=18)

# Setting font sizes
for ax in axs:
    ax.set_title(ax.get_title(), fontsize=16)
    ax.set_ylabel('MRR', fontsize=16)
    ax.set_xticks(x + 2 * width)
    ax.set_xticklabels(groups, fontsize=16)
    for label in ax.get_yticklabels():
        label.set_fontsize(16)

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Add a common legend at the top
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.99), ncol=5, prop={'size': 16})

# Display the plot
plt.show()

# %%
# Correct one

# Strategy names
strategies = ['UR', 'EF', 'GD', 'CC', 'CT']

# Model names and colors
models = ['ComplEx', 'ConvE', 'DistMult', 'RESCAL', 'TransE']
bar_colors = ['tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple']

# Bar plot configuration
x = np.arange(len(strategies))
width = 0.15

fig, axs = plt.subplots(2, 2, figsize=(10, 6))
axs = axs.flatten()

data_by_strategy = {
    'FB15K-237': [ur_fb_eff, ef_fb_eff, gd_fb_eff, cc_fb_eff, ct_fb_eff],
    'WN18RR': [ur_wn_eff, ef_wn_eff, gd_wn_eff, cc_wn_eff, ct_wn_eff],
    'CoDEx-L': [ur_cd_eff, ef_cd_eff, gd_cd_eff, cc_cd_eff, ct_cd_eff],
    'YAGO3-10': [ur_yg_eff, ef_yg_eff, gd_yg_eff, cc_yg_eff, ct_yg_eff]
}

titles = ["FB15K-237", "WN18RR", "CoDEx-L", "YAGO3-10"]

for ax_index, (ax, title) in enumerate(zip(axs, titles)):
    data_for_title = data_by_strategy[title]
    for model_index, model in enumerate(models):
        eff_values = [strategy_data[model_index] for strategy_data in data_for_title]
        ax.bar(x + model_index * width, eff_values, width, color=bar_colors[model_index], label=model, edgecolor='black')
    # ax.set_title(title)
    ax.set_ylabel('Eff  (Fact/h)')
    ax.set_xticks(x + 2 * width)
    ax.set_xticklabels(strategies)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Set titles with bold formatting (this will mimic LaTeX's bold, but won't be exactly the same)
axs[0].set_xlabel(r"\textbf{(a) FB15K-237}", fontsize=18)
axs[1].set_xlabel(r"\textbf{(b) WN18RR}", fontsize=18)
axs[2].set_xlabel(r"\textbf{(c) CoDEx-L}", fontsize=18)
axs[3].set_xlabel(r"\textbf{(d) YAGO3-10}", fontsize=18)

# Setting font sizes
for ax in axs:
    ax.set_title(ax.get_title(), fontsize=16)
    ax.set_ylabel('Eff (Facts/h)', fontsize=16)
    ax.set_xticks(x + 2 * width)
    ax.set_xticklabels(groups, fontsize=16)
    for label in ax.get_yticklabels():
        label.set_fontsize(16)

# Adjust spacing between subplots
plt.subplots_adjust(hspace=0.4, wspace=0.3)

# Add a common legend at the top
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 0.99), ncol=5, prop={'size': 16})

# Display the plot
plt.show()
